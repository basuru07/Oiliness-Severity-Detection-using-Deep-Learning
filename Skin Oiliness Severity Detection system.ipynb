# %%
pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# Using cached opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
# Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# ...
#   Using cached tensorflow-2.15.0-cp311-cp311-win_amd64.whl.metadata (3.6 kB)
# ...
#   Using cached tensorflow_intel-2.15.0-cp311-cp311-win_amd64.whl.metadata (5.1 kB)
# ...
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# ...
#   Using cached gast-0.5.4-py3-none-any.whl.metadata (1.3 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# ...
#   Using cached h5py-3.10.0-cp311-cp311-win_amd64.whl.metadata (2.5 kB)
# ...
#   Using cached libclang-16.0.6-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# ...
#   Using cached ml_dtypes-0.2.0-cp311-cp311-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# ...
#   Using cached protobuf-4.25.3-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# ...
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# ...

# %%
import cv2
import numpy as np
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model

# Function to preprocess a frame for VGG16
def preprocess_frame(frame):
    # Preprocess the frame for VGG16
    frame = cv2.resize(frame, (224, 224))
    frame = image.img_to_array(frame)
    frame = np.expand_dims(frame, axis=0)
    frame = preprocess_input(frame)
    return frame

# Function to build the oiliness detection model
def build_model():
    # Load the pre-trained VGG16 model without the top classification layer
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    
    # Freeze the layers of the pre-trained model
    for layer in base_model.layers:
        layer.trainable = False
    
    # Add custom layers for binary classification
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(256, activation='relu')(x)
    predictions = Dense(1, activation='sigmoid')(x)
    
    # Build the complete model
    model = Model(inputs=base_model.input, outputs=predictions)
    return model

# Function to detect oiliness severity in a given frame
def detect_oiliness(frame, model):
    # Preprocess the frame
    frame_array = preprocess_frame(frame)
    
    # Make predictions using the model
    prediction = model.predict(frame_array)
    
    # Classify severity based on the prediction
    severity_level = 1 if prediction < 0.5 else 3  # Binary classification
    return severity_level

# Build the model
oiliness_model = build_model()

# Open a connection to the webcam (usually index 0, but it may vary)
cap = cv2.VideoCapture(0)

while True:
    # Read a frame from the webcam
    ret, frame = cap.read()
    
    # Detect oiliness severity
    severity_level = detect_oiliness(frame, oiliness_model)
    
    # Display the severity level on the frame
    cv2.putText(frame, f"Oiliness Severity: {severity_level}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
    
    # Display the frame
    cv2.imshow('Oiliness Detection', frame)
    
    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close the window
cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:tensorflow:From C:\Users\Basuru Yasaruwan\Contacts\Desktop\IPCV Practicals\OILDetection\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\Basuru Yasaruwan\Contacts\Desktop\IPCV Practicals\OILDetection\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Basuru Yasaruwan\Contacts\Desktop\IPCV Practicals\OILDetection\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
